# %%
import pandas as pd
import os

# %%
enW = pd.read_csv (r'INT-Export-worldEnergyYearly.csv')

# %%
enW
# Out:
#      Report generated on: 12-29-2022 11:25:43  \
# 0                                         API
# 1                                         NaN
# 2                       INTL.44-1-WORL-QBTU.A
# 3                        INTL.44-1-AFG-QBTU.A
# 4                        INTL.44-1-ALB-QBTU.A
# ...                                       ...
# 1620                   INTL.4418-1-WAK-QBTU.A
# 1621                   INTL.4418-1-ESH-QBTU.A
# 1622                   INTL.4418-1-YEM-QBTU.A
# 1623                   INTL.4418-1-ZMB-QBTU.A
# 1624                   INTL.4418-1-ZWE-QBTU.A
#
#                               Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                                    NaN         1980         1981
# 1     total energy production (quad Btu)          NaN          NaN
# 2                                  World  296.3424356  291.2937659
# 3                            Afghanistan  0.072561156  0.092723655
# 4                                Albania   0.15556162  0.158691383
# ...

# %%
enW.columns = enW.iloc[0]

# %%
enW = enW.drop(['API'], axis=1)
#The API info is not needed

# %%
enW.rename(columns={ enW.columns[0]: 'Country Name'}, inplace = True)

# %%
enW
# Out:
# 0                           Country Name         1980         1981  \
# 0                                    NaN         1980         1981
# 1     total energy production (quad Btu)          NaN          NaN
# 2                                  World  296.3424356  291.2937659
# 3                            Afghanistan  0.072561156  0.092723655
# 4                                Albania   0.15556162  0.158691383
# ...                                  ...          ...          ...
# 1620                         Wake Island            0            0
# 1621                      Western Sahara            0            0
# 1622                               Yemen            0            0
# 1623                              Zambia   0.09359591  0.101143253
# 1624                            Zimbabwe  0.041981256  0.043344924
#
# 0            1982         1983         1984         1985         1986  \
# 0            1982         1983         1984         1985         1986
# ...

# %%
enW = enW.drop([0,1,2])

# %%
enW = enW.loc[0:232]
#changes to only energy consumption

# %%
enWA = enW['Country Name']

# %%
enWA
# Out:
# 3                 Afghanistan
# 4                     Albania
# 5                     Algeria
# 6              American Samoa
# 7                      Angola
#                 ...
# 228               Wake Island
# 229            Western Sahara
# 230                     Yemen
# 231                    Zambia
# 232                  Zimbabwe
# Name: Country Name, Length: 230, dtype: object

# %%
enWB = enW.drop(['Country Name'],axis =1)

# %%
enWB
# Out:
# 0           1980         1981         1982         1983         1984  \
# 3    0.072561156  0.092723655  0.095067867   0.09971282  0.099827343
# 4     0.15556162  0.158691383  0.205944156  0.234693222  0.191025062
# 5    2.803017355   3.03753686  3.224933779  3.606400483  3.859176003
# 6              0            0            0            0            0
# 7    0.335098042  0.291293691  0.276262403  0.395407667  0.462550452
# ..           ...          ...          ...          ...          ...
# 228            0            0            0            0            0
# 229            0            0            0            0            0
# 230            0            0            0            0            0
# 231  0.107536797  0.113570699  0.118436574  0.115553717  0.114707411
# 232  0.110369316  0.104469223  0.102144579  0.104210291  0.103660842
#
# 0           1985         1986         1987         1988         1989  ...  \
# ...

# %%
enWB = pd.melt(enWB)

# %%
enWA = pd.concat([enWA]*42, ignore_index=True) #1980-2021

# %%
enWA
# Out:
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                       Angola
#                  ...
# 9655               Wake Island
# 9656            Western Sahara
# 9657                     Yemen
# 9658                    Zambia
# 9659                  Zimbabwe
# Name: Country Name, Length: 9660, dtype: object

# %%
enW = pd.concat([enWA,enWB],axis=1)
enW
# Out:
#                 Country Name     0        value
# 0                Afghanistan  1980  0.072561156
# 1                    Albania  1980   0.15556162
# 2                    Algeria  1980  2.803017355
# 3             American Samoa  1980            0
# 4                     Angola  1980  0.335098042
# ...                      ...   ...          ...
# 9655             Wake Island  2021            0
# 9656          Western Sahara  2021            0
# 9657                   Yemen  2021  0.128637763
# 9658                  Zambia  2021   0.17007611
# 9659                Zimbabwe  2021  0.116297207
#
# [9660 rows x 3 columns]

# %%
gdpW = pd.read_csv (r'GDP WorldWide Resaved.csv')

# %%
gdpW.head(25)
# Out:
#                     Data Source World Development Indicators  \
# 0                           NaN                          NaN
# 1             Last Updated Date                   12/22/2022
# 2                           NaN                          NaN
# 3                  Country Name                 Country Code
# 4                         Aruba                          ABW
# 5   Africa Eastern and Southern                          AFE
# 6                   Afghanistan                          AFG
# 7    Africa Western and Central                          AFW
# 8                        Angola                          AGO
# 9                       Albania                          ALB
# 10                      Andorra                          AND
# 11                   Arab World                          ARB
# 12         United Arab Emirates                          ARE
# 13                    Argentina                          ARG
# ...

# %%
gdpW.columns = gdpW.iloc[3].astype(str)

# %%
gdpW = gdpW.drop([0,1,2,3])

# %%
gdpW
# Out:
# 3                   Country Name Country Code     Indicator Name  \
# 4                          Aruba          ABW  GDP (current US$)
# 5    Africa Eastern and Southern          AFE  GDP (current US$)
# 6                    Afghanistan          AFG  GDP (current US$)
# 7     Africa Western and Central          AFW  GDP (current US$)
# 8                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 265                       Kosovo          XKX  GDP (current US$)
# 266                  Yemen, Rep.          YEM  GDP (current US$)
# 267                 South Africa          ZAF  GDP (current US$)
# 268                       Zambia          ZMB  GDP (current US$)
# 269                     Zimbabwe          ZWE  GDP (current US$)
#
# 3    Indicator Code        1960.0        1961.0        1962.0        1963.0  \
# 4    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
gdpWA = gdpW.loc[:, '1980.0':'2021.0'] #This is the year range for the energy dataset

# %%
gdpWA
# Out:
# 3          1980.0        1981.0        1982.0        1983.0        1984.0  \
# 4             NaN           NaN           NaN           NaN           NaN
# 5    1.706560e+11  1.743890e+11  1.672680e+11  1.749200e+11  1.601360e+11
# 6    3.641723e+09  3.478788e+09           NaN           NaN           NaN
# 7    1.120310e+11  2.110030e+11  1.871640e+11  1.381150e+11  1.142630e+11
# 8    5.930503e+09  5.550483e+09  5.550483e+09  5.784342e+09  6.131475e+09
# ..            ...           ...           ...           ...           ...
# 265           NaN           NaN           NaN           NaN           NaN
# 266           NaN           NaN           NaN           NaN           NaN
# 267  8.941189e+10  9.314148e+10  8.590407e+10  9.620411e+10  8.487013e+10
# 268  3.829500e+09  3.872667e+09  3.994778e+09  3.216308e+09  2.739444e+09
# 269  6.678868e+09  8.011374e+09  8.539701e+09  7.764067e+09  6.352126e+09
#
# 3          1985.0        1986.0        1987.0        1988.0        1989.0  \
# ...

# %%
gdpWA = pd.melt(gdpWA)

# %%
gdpWA[3] = gdpWA[3].astype(float)

# %%
gdpWA[3] = gdpWA[3].astype(int)

# %%
gdpWB = gdpW['Country Name']

# %%
gdpWB.astype(str)
# Out:
# 4                            Aruba
# 5      Africa Eastern and Southern
# 6                      Afghanistan
# 7       Africa Western and Central
# 8                           Angola
#                   ...
# 265                         Kosovo
# 266                    Yemen, Rep.
# 267                   South Africa
# 268                         Zambia
# 269                       Zimbabwe
# Name: Country Name, Length: 266, dtype: object

# %%
gdpWB = pd.concat([gdpWB]*42, ignore_index=True)

# %%
gdpWB
# Out:
# 0                              Aruba
# 1        Africa Eastern and Southern
# 2                        Afghanistan
# 3         Africa Western and Central
# 4                             Angola
#                     ...
# 11167                         Kosovo
# 11168                    Yemen, Rep.
# 11169                   South Africa
# 11170                         Zambia
# 11171                       Zimbabwe
# Name: Country Name, Length: 11172, dtype: object

# %%
gdpW = pd.concat([gdpWB,gdpWA], axis=1)

# %%
gdpW
# Out:
#                       Country Name     3         value
# 0                            Aruba  1980           NaN
# 1      Africa Eastern and Southern  1980  1.706560e+11
# 2                      Afghanistan  1980  3.641723e+09
# 3       Africa Western and Central  1980  1.120310e+11
# 4                           Angola  1980  5.930503e+09
# ...                            ...   ...           ...
# 11167                       Kosovo  2021  9.412034e+09
# 11168                  Yemen, Rep.  2021           NaN
# 11169                 South Africa  2021  4.190150e+11
# 11170                       Zambia  2021  2.214763e+10
# 11171                     Zimbabwe  2021  2.837124e+10
#
# [11172 rows x 3 columns]

# %%
enW.dtypes
# Out:
# Country Name    object
# 0               object
# value           object
# dtype: object

# %%
gdpW.dtypes
# Out:
# Country Name     object
# 3                 int32
# value           float64
# dtype: object

# %%
enW
# Out:
#                 Country Name     0        value
# 0                Afghanistan  1980  0.072561156
# 1                    Albania  1980   0.15556162
# 2                    Algeria  1980  2.803017355
# 3             American Samoa  1980            0
# 4                     Angola  1980  0.335098042
# ...                      ...   ...          ...
# 9655             Wake Island  2021            0
# 9656          Western Sahara  2021            0
# 9657                   Yemen  2021  0.128637763
# 9658                  Zambia  2021   0.17007611
# 9659                Zimbabwe  2021  0.116297207
#
# [9660 rows x 3 columns]

# %%
enW = enW.replace({'--':'0', '':'0'}) #replace the -- and blank spaces with 0

# %%
enW['Country Name'] = enW['Country Name'].astype(str)
enW[0]= enW[0].astype(int)
enW['value'] = enW['value'].astype(float)
gdpW['Country Name'] = gdpW['Country Name'].astype(str)
#data type cleanup

# %%
enW.dtypes
# Out:
# Country Name     object
# 0                 int32
# value           float64
# dtype: object

# %%
gdpW
# Out:
#                       Country Name     3         value
# 0                            Aruba  1980           NaN
# 1      Africa Eastern and Southern  1980  1.706560e+11
# 2                      Afghanistan  1980  3.641723e+09
# 3       Africa Western and Central  1980  1.120310e+11
# 4                           Angola  1980  5.930503e+09
# ...                            ...   ...           ...
# 11167                       Kosovo  2021  9.412034e+09
# 11168                  Yemen, Rep.  2021           NaN
# 11169                 South Africa  2021  4.190150e+11
# 11170                       Zambia  2021  2.214763e+10
# 11171                     Zimbabwe  2021  2.837124e+10
#
# [11172 rows x 3 columns]

# %%
enW
# Out:
#                 Country Name     0     value
# 0                Afghanistan  1980  0.072561
# 1                    Albania  1980  0.155562
# 2                    Algeria  1980  2.803017
# 3             American Samoa  1980  0.000000
# 4                     Angola  1980  0.335098
# ...                      ...   ...       ...
# 9655             Wake Island  2021  0.000000
# 9656          Western Sahara  2021  0.000000
# 9657                   Yemen  2021  0.128638
# 9658                  Zambia  2021  0.170076
# 9659                Zimbabwe  2021  0.116297
#
# [9660 rows x 3 columns]

# %%
#gdpW.to_csv('gdpW.csv',index=None)
#enW.to_csv('enW.csv',index=None)

# %% [markdown]
# The enW data has spaces infornt of the countries...

# %%
enW['Country Name']= enW['Country Name'].str.strip()

# %%
gdpW = gdpW.rename(columns={3:'Year'})

# %%
enW = enW.rename(columns ={0:'Year'})

# %%
dataW = pd.merge(enW, gdpW, how='left', on=['Country Name','Year'])
dataW
# Out:
#         Country Name  Year   value_x       value_y
# 0        Afghanistan  1980  0.072561  3.641723e+09
# 1            Albania  1980  0.155562           NaN
# 2            Algeria  1980  2.803017  4.234638e+10
# 3     American Samoa  1980  0.000000           NaN
# 4             Angola  1980  0.335098  5.930503e+09
# ...              ...   ...       ...           ...
# 9655     Wake Island  2021  0.000000           NaN
# 9656  Western Sahara  2021  0.000000           NaN
# 9657           Yemen  2021  0.128638           NaN
# 9658          Zambia  2021  0.170076  2.214763e+10
# 9659        Zimbabwe  2021  0.116297  2.837124e+10
#
# [9660 rows x 4 columns]

# %%
dataW = dataW.dropna()

# %%
dataW
# Out:
#              Country Name  Year   value_x       value_y
# 0             Afghanistan  1980  0.072561  3.641723e+09
# 2                 Algeria  1980  2.803017  4.234638e+10
# 4                  Angola  1980  0.335098  5.930503e+09
# 6     Antigua and Barbuda  1980  0.000000  1.314310e+08
# 7               Argentina  1980  1.597946  7.696192e+10
# ...                   ...   ...       ...           ...
# 9651           Uzbekistan  2021  1.983724  6.923890e+10
# 9652              Vanuatu  2021  0.000116  9.563327e+08
# 9654              Vietnam  2021  2.713688  3.661380e+11
# 9658               Zambia  2021  0.170076  2.214763e+10
# 9659             Zimbabwe  2021  0.116297  2.837124e+10
#
# [6744 rows x 4 columns]

# %%
dataW = dataW[dataW['value_x'] != 0.00] #remove the data that was blank or -- that was set to 0.00 in order to make the column a float

# %%
dataW #5957 usable data points for machine learning model of GDP vs Energy Production
# Out:
#      Country Name  Year   value_x       value_y
# 0     Afghanistan  1980  0.072561  3.641723e+09
# 2         Algeria  1980  2.803017  4.234638e+10
# 4          Angola  1980  0.335098  5.930503e+09
# 7       Argentina  1980  1.597946  7.696192e+10
# 10      Australia  1980  3.722297  1.499840e+11
# ...           ...   ...       ...           ...
# 9651   Uzbekistan  2021  1.983724  6.923890e+10
# 9652      Vanuatu  2021  0.000116  9.563327e+08
# 9654      Vietnam  2021  2.713688  3.661380e+11
# 9658       Zambia  2021  0.170076  2.214763e+10
# 9659     Zimbabwe  2021  0.116297  2.837124e+10
#
# [5957 rows x 4 columns]

# %%
dataW = dataW.rename(columns = {'value_x':'Energy Production Quad BTU', 'value_y':'GDP'})

# %%
dataW
# Out:
#      Country Name  Year  Energy Production Quad BTU           GDP
# 0     Afghanistan  1980                    0.072561  3.641723e+09
# 2         Algeria  1980                    2.803017  4.234638e+10
# 4          Angola  1980                    0.335098  5.930503e+09
# 7       Argentina  1980                    1.597946  7.696192e+10
# 10      Australia  1980                    3.722297  1.499840e+11
# ...           ...   ...                         ...           ...
# 9651   Uzbekistan  2021                    1.983724  6.923890e+10
# 9652      Vanuatu  2021                    0.000116  9.563327e+08
# 9654      Vietnam  2021                    2.713688  3.661380e+11
# 9658       Zambia  2021                    0.170076  2.214763e+10
# 9659     Zimbabwe  2021                    0.116297  2.837124e+10
#
# [5957 rows x 4 columns]

# %%
dataW.to_csv('dataW.csv',index=None)
