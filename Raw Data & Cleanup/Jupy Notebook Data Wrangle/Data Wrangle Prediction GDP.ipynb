# %% [markdown]
# Predicted GDP pulled from: https://data.oecd.org/gdp/real-gdp-long-term-forecast.htm#indicator-chart
#
# 10 Countries selected for the Years 2020 - 2060
#
# 1)  Canada
# 2)  China
# 3)  Colombia
# 4)  Finland
# 5)  United Kingdom (UK)
# 6)  India
# 7)  Iceland
# 8)  Italy
# 9)  Mexico
# 10) United States (US)

# %%
import pandas as pd
import os

# %%
dataP = pd.read_csv('DP_LIVE_23012023033418205.csv')

# %%
dataP
# Out:
#     LOCATION      INDICATOR SUBJECT  MEASURE FREQUENCY  TIME        Value  \
# 0        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2020  1638195.720
# 1        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2021  1738685.474
# 2        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2022  1803949.390
# 3        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2023  1845470.000
# 4        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2024  1879382.000
# ..       ...            ...     ...      ...       ...   ...          ...
# 405      COL  GDPLTFORECAST     TOT  MLN_USD         A  2056  1252909.000
# 406      COL  GDPLTFORECAST     TOT  MLN_USD         A  2057  1262436.000
# 407      COL  GDPLTFORECAST     TOT  MLN_USD         A  2058  1271824.000
# 408      COL  GDPLTFORECAST     TOT  MLN_USD         A  2059  1281148.000
# 409      COL  GDPLTFORECAST     TOT  MLN_USD         A  2060  1290494.000
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# ...

# %% [markdown]
# The GDP is for Millions in USD but it wasn't exported that way like the original GDP data.

# %%
dataP.dtypes
# Out:
# LOCATION       object
# INDICATOR      object
# SUBJECT        object
# MEASURE        object
# FREQUENCY      object
# TIME            int64
# Value         float64
# Flag Codes    float64
# dtype: object

# %%
dataP['Value'] = dataP['Value']*10**6

# %%
dataP
# Out:
#     LOCATION      INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 0        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2020  1.638196e+12
# 1        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2021  1.738685e+12
# 2        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2022  1.803949e+12
# 3        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2023  1.845470e+12
# 4        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2024  1.879382e+12
# ..       ...            ...     ...      ...       ...   ...           ...
# 405      COL  GDPLTFORECAST     TOT  MLN_USD         A  2056  1.252909e+12
# 406      COL  GDPLTFORECAST     TOT  MLN_USD         A  2057  1.262436e+12
# 407      COL  GDPLTFORECAST     TOT  MLN_USD         A  2058  1.271824e+12
# 408      COL  GDPLTFORECAST     TOT  MLN_USD         A  2059  1.281148e+12
# 409      COL  GDPLTFORECAST     TOT  MLN_USD         A  2060  1.290494e+12
#
#      Flag Codes
# 0           NaN
# 1           NaN
# ...

# %%
dataRef = pd.read_csv (r'GDP WorldWide Resaved.csv')

# %%
dataRef.columns = dataRef.iloc[3].astype(str)

# %%
dataRef.head(50)
# Out:
# 3                     Country Name  Country Code     Indicator Name  \
# 0                              NaN           NaN                NaN
# 1                Last Updated Date    12/22/2022                NaN
# 2                              NaN           NaN                NaN
# 3                     Country Name  Country Code     Indicator Name
# 4                            Aruba           ABW  GDP (current US$)
# 5      Africa Eastern and Southern           AFE  GDP (current US$)
# 6                      Afghanistan           AFG  GDP (current US$)
# 7       Africa Western and Central           AFW  GDP (current US$)
# 8                           Angola           AGO  GDP (current US$)
# 9                          Albania           ALB  GDP (current US$)
# 10                         Andorra           AND  GDP (current US$)
# 11                      Arab World           ARB  GDP (current US$)
# 12            United Arab Emirates           ARE  GDP (current US$)
# ...

# %%
dataRef.loc[39]
# Out:
# 3
# Country Name                 Canada
# Country Code                    CAN
# Indicator Name    GDP (current US$)
# Indicator Code       NY.GDP.MKTP.CD
# 1960.0                40461721693.0
#                         ...
# 2017.0              1649270000000.0
# 2018.0              1725330000000.0
# 2019.0              1742020000000.0
# 2020.0              1645420000000.0
# 2021.0              1988340000000.0
# Name: 39, Length: 66, dtype: object

# %%
#1645420000000

# %%
import math

# %%
X = 1645420000000/1.638196e+12 #ref/pred

# %%
X
# Out:
# 1.004409728750406

# %% [markdown]
# Near perfect match, the data is good to use now.

# %%
dataP
# Out:
#     LOCATION      INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 0        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2020  1.638196e+12
# 1        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2021  1.738685e+12
# 2        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2022  1.803949e+12
# 3        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2023  1.845470e+12
# 4        CAN  GDPLTFORECAST     TOT  MLN_USD         A  2024  1.879382e+12
# ..       ...            ...     ...      ...       ...   ...           ...
# 405      COL  GDPLTFORECAST     TOT  MLN_USD         A  2056  1.252909e+12
# 406      COL  GDPLTFORECAST     TOT  MLN_USD         A  2057  1.262436e+12
# 407      COL  GDPLTFORECAST     TOT  MLN_USD         A  2058  1.271824e+12
# 408      COL  GDPLTFORECAST     TOT  MLN_USD         A  2059  1.281148e+12
# 409      COL  GDPLTFORECAST     TOT  MLN_USD         A  2060  1.290494e+12
#
#      Flag Codes
# 0           NaN
# 1           NaN
# ...

# %%
dataP = dataP[['LOCATION','TIME','Value']]

# %%
dataP
# Out:
#     LOCATION  TIME         Value
# 0        CAN  2020  1.638196e+12
# 1        CAN  2021  1.738685e+12
# 2        CAN  2022  1.803949e+12
# 3        CAN  2023  1.845470e+12
# 4        CAN  2024  1.879382e+12
# ..       ...   ...           ...
# 405      COL  2056  1.252909e+12
# 406      COL  2057  1.262436e+12
# 407      COL  2058  1.271824e+12
# 408      COL  2059  1.281148e+12
# 409      COL  2060  1.290494e+12
#
# [410 rows x 3 columns]

# %%
dataP.to_csv('dataP.csv')
