# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# %%
modelKN = pickle.load(open('KNeigh.pkl', 'rb'))

# %%
dataP = pd.read_csv (r'dataP.csv')

# %%
dataP = dataP[['LOCATION','TIME','Value']]

# %%
dataP
# Out:
#     LOCATION  TIME         Value
# 0        CAN  2020  1.638196e+12
# 1        CAN  2021  1.738685e+12
# 2        CAN  2022  1.803949e+12
# 3        CAN  2023  1.845470e+12
# 4        CAN  2024  1.879382e+12
# ..       ...   ...           ...
# 405      COL  2056  1.252909e+12
# 406      COL  2057  1.262436e+12
# 407      COL  2058  1.271824e+12
# 408      COL  2059  1.281148e+12
# 409      COL  2060  1.290494e+12
#
# [410 rows x 3 columns]

# %%
dataCanada = dataP.iloc[0:41]
XCanada = dataCanada.iloc[:,2].values.reshape(-1,1)
yCanada = modelKN.predict(XCanada)

# %%
plt.scatter(XCanada,yCanada)
plt.title('Canada Prediction')
plt.xlabel('GDP')
plt.ylabel('Energy Production Quad BTU')
# Out:
# Text(0, 0.5, 'Energy Production Quad BTU')

# %%
dataFinland = dataP.iloc[42:82]
XFinland = dataFinland.iloc[:,2].values.reshape(-1,1)
yFinland = modelKN.predict(XFinland)

# %%
plt.scatter(XFinland,yFinland)
plt.title('Finland Prediction')
plt.xlabel('GDP')
plt.ylabel('Energy Production Quad BTU')
# Out:
# Text(0, 0.5, 'Energy Production Quad BTU')

# %%
dataIceland = dataP.iloc[83:123]
XIceland = dataIceland.iloc[:,2].values.reshape(-1,1)
yIceland = modelKN.predict(XIceland)

# %%
plt.scatter(XIceland,yIceland)
plt.title('Iceland Prediction')
plt.xlabel('GDP')
plt.ylabel('Energy Production Quad BTU')
# Out:
# Text(0, 0.5, 'Energy Production Quad BTU')

# %%
dataUSA = dataP.iloc[246:287]
XUSA = dataUSA.iloc[:,2].values.reshape(-1,1)
yUSA = modelKN.predict(XUSA)

# %%
plt.scatter(XUSA,yUSA)
plt.title('USA Prediction')
plt.xlabel('GDP')
plt.ylabel('Energy Production Quad BTU')
# Out:
# Text(0, 0.5, 'Energy Production Quad BTU')
